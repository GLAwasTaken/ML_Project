# %% [markdown]
# # Machine Learning project

# %% [markdown]
# ### Gruppo 7:
# - **Emanuele Conforti (252122)**
# - **Jacopo Garofalo (252093)**
# - **Gianmarco La Marca (252256)**

# %% [markdown]
# ## **Heart disease Dataset**

# %% [markdown]
# ### **Business Understanding**
#
# - **Scenario**
#     - CMS compiles claims data for Medicare and Medicaid patients across a variety of categories and years. This includes Inpatient and Outpatient claims, Master Beneficiary Summary Files, and many other files. Indicators from this data source have been computed by personnel in CDC's Division for Heart Disease and Stroke Prevention (DHDSP).
# The system is designed to integrate multiple indicators from many data sources to provide a comprehensive picture of the public health burden of CVDs and associated risk factors in the United States. The data are organized by location (national and state) and indicator. The data can be plotted as trends and stratified by sex and race/ethnicity.
# - **Goal**
#     - Define an automatic procedure for categorizing cardiovascular diseases

# %% [markdown]
# ### **Data Understanding**

# %% [markdown]
# | Column Name                   	 | Description                                                                                                     	| Type                      	         |
# |------------------------------|------------------------------------------------	|-------------------------------------|
# | Year               	         | Year                    	| Numeric                      	      |
# | LocationAbbr               	 | Location abbreviation                 	| Categorical             	           |
# | LocationDesc                	 | Location description      	| Categorical                      	  |
# | DataSource        	          |        Abbreviation of data source       	| Categorical                       	 |
# | PriorityArea1         	      |   Priority Area (Million Hearts® or None)          	| Categorical    	                    |
# | PriorityArea2           	    |    Priority Area (ABCS or None)       | Categorical                         |
# | PriorityArea3          	     |   Priority Area (Healthy People 2020 or None)        	| Categorical                       	 |
# | PriorityArea4          	     |      Priority Area (AHA 2020 Goals: Cardiovascular Health Metrics or None)            	| Categorical                    	    |
# | Category               	     | Category description                    	| Categorical                      	  |
# | Topic               	        | Topic description                 	| Categorical             	           |
# | Indicator                	   | Indicator description      	| Categorical                      	  |
# | Data_Value_Type        	          |        Data Value Type (mean, rate, percentage)       	| Categorical                       	 |
# | Data_Value_Unit         	      |   Data Value Unit (%, rate per 100,000, etc.)          	| Categorical    	                    |
# | Data_Value           	               |    Data value (point estimate)       | Numeric                             |
# | Data_Value_Alt          	                 |   Equal to data value, but formatting is numeric        	| Numeric                       	     |
# | Data_Value_Footnote_Symbol          	              |      Symbol that would be used to flag footnotes            	| Categorical                    	    |
# | Data_Value_Footnote               	         | Footnote description                    	| Numeric                      	      |
# | LowConfidenceLimit               	 | 95% confidence interval lower bound                 	| Numeric             	               |
# | HighConfidenceLimit                	 | 95% confidence interval upper bound      	| Numeric                      	      |
# | Break_Out_Category        	          |        Break out category description       	| Categorical                       	 |
# | Break_Out         	      |   Break out group description          	| Categorical    	                    |
# | CategoryId           	               |    Category lookup value       | Categorical                         |
# | TopicId          	                 |   Topic lookup value        	| Categorical                       	 |
# | IndicatorID          	              |      Indicator lookup value            	| Categorical                    	    |
# | Data_Value_TypeID                	 | Data value type lookup value      	| Categorical                      	  |
# | BreakOutCategoryId        	          |        Break out category lookup value       	| Categorical                       	 |
# | BreakOutId         	      |   Break out group lookup value          	| Categorical    	                    |
# | LocationID        	          |        Location lookup value       	| Numeric                       	     |
# | GeoLocation         	      |   Latitude & Longitude to be provided for formatting GeoLocation or Geocode in the format (latitude, longitude)          	| Categorical    	                    |

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
plt.style.use('ggplot')

df = pd.read_csv('heart_disease_data.csv')
df
# Out:
#        Year LocationAbbr   LocationDesc DataSource   PriorityArea1  \
# 0      2006           US  United States   Medicare             NaN
# 1      2005           US  United States   Medicare             NaN
# 2      2007           US  United States   Medicare             NaN
# 3      2008           US  United States   Medicare             NaN
# 4      2004           US  United States   Medicare             NaN
# ...     ...          ...            ...        ...             ...
# 42635  2012           CO       Colorado   Medicare  Million Hearts
# 42636  2010           MI       Michigan   Medicare  Million Hearts
# 42637  2012           ME          Maine   Medicare  Million Hearts
# 42638  2013           ID          Idaho   Medicare  Million Hearts
# 42639  2012           IA           Iowa   Medicare  Million Hearts
#
#        PriorityArea2 PriorityArea3  PriorityArea4                 Category  \
# 0                NaN           NaN            NaN  Cardiovascular Diseases
# 1                NaN           NaN            NaN  Cardiovascular Diseases
# 2                NaN           NaN            NaN  Cardiovascular Diseases
# 3                NaN           NaN            NaN  Cardiovascular Diseases
# 4                NaN           NaN            NaN  Cardiovascular Diseases
# ...              ...           ...            ...                      ...
# 42635            NaN           NaN            NaN  Cardiovascular Diseases
# 42636            NaN           NaN            NaN  Cardiovascular Diseases
# 42637            NaN           NaN            NaN  Cardiovascular Diseases
# 42638            NaN           NaN            NaN  Cardiovascular Diseases
# 42639            NaN           NaN            NaN  Cardiovascular Diseases
#
#                         Topic  ... Break_Out_Category           Break_Out  \
# 0               Heart Failure  ...               Race               Other
# 1               Heart Failure  ...               Race               Other
# 2      Coronary Heart Disease  ...                Age                 65+
# 3      Coronary Heart Disease  ...             Gender              Female
# 4               Heart Failure  ...            Overall             Overall
# ...                       ...  ...                ...                 ...
# 42635                  Stroke  ...             Gender                Male
# 42636                  Stroke  ...             Gender              Female
# 42637                  Stroke  ...               Race            Hispanic
# 42638                  Stroke  ...               Race  Non-Hispanic White
# 42639                  Stroke  ...             Gender                Male
#
#       CategoryId  TopicId  IndicatorID Data_Value_TypeID BreakOutCategoryId  \
# 0             C1       T5        MD501             Crude              BOC04
# 1             C1       T5        MD501             Crude              BOC04
# 2             C1       T4        MD301             Crude              BOC03
# 3             C1       T4        MD301             Crude              BOC02
# 4             C1       T5        MD501             Crude              BOC01
# ...          ...      ...          ...               ...                ...
# 42635         C1       T6        MD601             Crude              BOC02
# 42636         C1       T6        MD601             Crude              BOC02
# 42637         C1       T6        MD601             Crude              BOC04
# 42638         C1       T6        MD601             Crude              BOC04
# 42639         C1       T6        MD601             Crude              BOC02
#
#        BreakOutId  LocationID                                GeoLocation
# 0           RAC07          59                                        NaN
# 1           RAC07          59                                        NaN
# 2           AGE06          59                                        NaN
# 3           GEN02          59                                        NaN
# 4           OVR01          59                                        NaN
# ...           ...         ...                                        ...
# 42635       GEN01           8  (38.843840757000464, -106.13361092099967)
# 42636       GEN02          26     (44.6613195430005, -84.71439026999968)
# 42637       RAC04          23   (45.254228894000505, -68.98503133599962)
# 42638       RAC01          16   (43.682630005000476, -114.3637300419997)
# 42639       GEN01          19    (42.46940091300047, -93.81649055599968)
#
# [42640 rows x 29 columns]

# %% [markdown]
# #### **Number of rows and cols**

# %%
df.shape
# Out:
# (42640, 29)

# %% [markdown]
# #### **Number of elements in the matrix**

# %%
df.size
# Out:
# 1236560

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42640 entries, 0 to 42639
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        42640 non-null  int64
#  1   LocationAbbr                42640 non-null  object
#  2   LocationDesc                42640 non-null  object
#  3   DataSource                  42640 non-null  object
#  4   PriorityArea1               9360 non-null   object
#  5   PriorityArea2               0 non-null      float64
#  6   PriorityArea3               14560 non-null  object
#  7   PriorityArea4               0 non-null      float64
#  8   Category                    42640 non-null  object
#  9   Topic                       42640 non-null  object
#  10  Indicator                   42640 non-null  object
#  11  Data_Value_Type             42640 non-null  object
#  12  Data_Value_Unit             42640 non-null  object
#  13  Data_Value                  42111 non-null  float64
#  14  Data_Value_Alt              42640 non-null  float64
#  15  Data_Value_Footnote_Symbol  529 non-null    object
#  16  Data_Value_Footnote         529 non-null    object
#  17  LowConfidenceLimit          42111 non-null  float64
#  18  HighConfidenceLimit         42111 non-null  float64
#  19  Break_Out_Category          42640 non-null  object
#  20  Break_Out                   42640 non-null  object
#  21  CategoryId                  42640 non-null  object
#  22  TopicId                     42640 non-null  object
#  23  IndicatorID                 42640 non-null  object
#  24  Data_Value_TypeID           42640 non-null  object
#  25  BreakOutCategoryId          42640 non-null  object
#  26  BreakOutId                  42640 non-null  object
#  27  LocationID                  42640 non-null  int64
#  28  GeoLocation                 41820 non-null  object
# dtypes: float64(6), int64(2), object(21)
# memory usage: 9.4+ MB

# %%
df.describe().T
# Out:
#                        count         mean        std     min      25%     50%  \
# Year                 42640.0  2008.500000   2.872315  2004.0  2006.00  2008.5
# PriorityArea2            0.0          NaN        NaN     NaN      NaN     NaN
# PriorityArea4            0.0          NaN        NaN     NaN      NaN     NaN
# Data_Value           42111.0    14.780896  13.286487     0.4     4.50    10.7
# Data_Value_Alt       42640.0    14.572709  13.333826    -2.0     4.40    10.4
# LowConfidenceLimit   42111.0    12.661509  11.453615     0.0     3.80     8.2
# HighConfidenceLimit  42111.0    17.074028  17.910274     1.1     5.00    12.7
# LocationID           42640.0    29.538462  16.064317     1.0    16.75    29.5
#
#                         75%     max
# Year                 2011.0  2013.0
# PriorityArea2           NaN     NaN
# PriorityArea4           NaN     NaN
# Data_Value             21.6   333.3
# Data_Value_Alt         21.5   333.3
# LowConfidenceLimit     19.6    94.2
# HighConfidenceLimit    23.4   710.5
# LocationID             42.5    59.0

# %% [markdown]
# #### **Missing values**

# %%
df.isna().sum()
# Out:
# Year                              0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# PriorityArea1                 33280
# PriorityArea2                 42640
# PriorityArea3                 28080
# PriorityArea4                 42640
# Category                          0
# Topic                             0
# Indicator                         0
# Data_Value_Type                   0
# Data_Value_Unit                   0
# Data_Value                      529
# Data_Value_Alt                    0
# Data_Value_Footnote_Symbol    42111
# Data_Value_Footnote           42111
# LowConfidenceLimit              529
# HighConfidenceLimit             529
# Break_Out_Category                0
# Break_Out                         0
# CategoryId                        0
# TopicId                           0
# IndicatorID                       0
# Data_Value_TypeID                 0
# BreakOutCategoryId                0
# BreakOutId                        0
# LocationID                        0
# GeoLocation                     820
# dtype: int64

# %% [markdown]
# There's some missing value for attributes:
# - *PriorityArea1*
# - *PriorityArea2*
# - *PriorityArea3*
# - *PriorityArea4*
# - *Data_Value*
# - *Data_Value_Footnote_Symbol*
# - *Data_Value_Footnote*
# - *LowConfidenceLimit*
# - *HighConfidenceLimit*
# - *GeoLocation*

# %%
threshold = 65/100 * df.shape[0]

for x in df.columns:
    if df[x].isna().sum() > threshold:
        df = df[df.columns.difference([x])]

df.shape
# Out:
# (42640, 23)

# %% [markdown]
# The following attributes have been deleted because they had more than 65% of missing values:
# - **PriorityArea1**
# - **PriorityArea2**
# - **PriorityArea3**
# - **PriorityArea4**
# - **Data_Value_Footnote_Symbol**
# - **Data_Value_Footnote**

# %% [markdown]
# #### **Removing attributes strongly correlated**

# %% [markdown]
# The correlated attributes are:
# - **Topic** and **TopicId**
# - **Break_out** and **BreakOutId**
# - **Break_out_category** and **BreakOutCategoryId**
# - **Category** and **CategoryID**
# - **LocationAbbr** and **LocationID**, **Geolocation**, **LocationDesc**
# - **Data_value_type** and **Data_Value_TypeID**
# - **Indicator** and **IndicatorID** (we remove both)

# %%
df = df[df.columns.difference(['TopicId', 'BreakOutId', 'BreakOutCategoryId', 'CategoryId', 'LocationDesc', 'GeoLocation', 'LocationID', 'Data_Value_TypeID', 'Indicator', 'IndicatorID'])]
df.head()
# Out:
#   Break_Out Break_Out_Category                 Category DataSource  \
# 0     Other               Race  Cardiovascular Diseases   Medicare
# 1     Other               Race  Cardiovascular Diseases   Medicare
# 2       65+                Age  Cardiovascular Diseases   Medicare
# 3    Female             Gender  Cardiovascular Diseases   Medicare
# 4   Overall            Overall  Cardiovascular Diseases   Medicare
#
#    Data_Value  Data_Value_Alt Data_Value_Type Data_Value_Unit  \
# 0         5.2             5.2           Crude     Percent (%)
# 1         5.1             5.1           Crude     Percent (%)
# 2         8.5             8.5           Crude     Percent (%)
# 3         5.1             5.1           Crude     Percent (%)
# 4         6.1             6.1           Crude     Percent (%)
#
#    HighConfidenceLimit LocationAbbr  LowConfidenceLimit  \
# 0                  5.3           US                 5.1
# 1                  5.2           US                 5.1
# 2                  8.5           US                 8.4
# 3                  5.1           US                 5.1
# 4                  6.1           US                 6.1
#
#                     Topic  Year
# 0           Heart Failure  2006
# 1           Heart Failure  2005
# 2  Coronary Heart Disease  2007
# 3  Coronary Heart Disease  2008
# 4           Heart Failure  2004

# %% [markdown]
# #### **Convert object type attributes into categorical attributes**

# %% [markdown]
# Attribute to convert:
# - Break_Out
# - Break_Out_Category
# - Category
# - DataSource
# - Data_Value_Type
# - Data_Value_Unit
# - LocationAbbr
# - Topic

# %%
for attribute in df.columns:
    if df[attribute].dtype == object:
        df[attribute] = df[attribute].astype('category')
        
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42640 entries, 0 to 42639
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Break_Out            42640 non-null  category
#  1   Break_Out_Category   42640 non-null  category
#  2   Category             42640 non-null  category
#  3   DataSource           42640 non-null  category
#  4   Data_Value           42111 non-null  float64
#  5   Data_Value_Alt       42640 non-null  float64
#  6   Data_Value_Type      42640 non-null  category
#  7   Data_Value_Unit      42640 non-null  category
#  8   HighConfidenceLimit  42111 non-null  float64
#  9   LocationAbbr         42640 non-null  category
#  10  LowConfidenceLimit   42111 non-null  float64
#  11  Topic                42640 non-null  category
#  12  Year                 42640 non-null  int64
# dtypes: category(8), float64(4), int64(1)
# memory usage: 2.0 MB

# %% [markdown]
# #### **Building histograms**

# %%
df.hist(figsize = (20, 15))
plt.show()

# %% [markdown]
# ##### **Bar plots for categorical attributes**

# %%
# categoricalAttributes = ['Break_Out', 'Break_Out_Category', 'Category', 'DataSource', 'Data_Value_Type', 'Data_Value_Unit', 'LocationAbbr', 'Topic']
for attribute in df.select_dtypes(include=["category"]):
    val = df[attribute].value_counts()
    val.plot(kind = 'bar', figsize = (10, 6))
    plt.ylabel('count')
    plt.xlabel(attribute)
    plt.show()

# %% [markdown]
# #### **Histograms and bar plots according to the class attributes**

# %%
import seaborn as sb

# %%
attributes =  df.columns.difference(['Year', 'Category', 'Data_Value_Type', 'DataSource', 'Topic'])

for attribute in attributes:
    plt.figure(figsize=(12,6))
    sb.histplot(x = df[attribute], hue = 'Topic', data = df, kde=True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 attributes =  df.columns.difference(['Year', 'Category', 'Data_Value_Type', 'DataSource', 'Topic'])
#       3 for attribute in attributes:
#       4     plt.figure(figsize=(12,6))
#
# NameError: name 'df' is not defined

# %%
df.plot(kind='box', subplots=True, sharex=False, sharey=False, figsize=(15, 27), layout=(5, 4))
plt.show()

# %%
sb.pairplot(df, hue = 'Topic')
plt.show()

# %%
plt.figure(figsize=(15, 7))
sb.heatmap(df.corr(numeric_only=True), annot=True, cmap='magma', fmt='.2f')
plt.show()

# %% [markdown]
# ### **Data Preparation**

# %% [markdown]
# **Remove Year attribute because it has a constant distribution (trivial, low variability)**

# %%
df = df[df.columns.difference(['Year'])]

# %% [markdown]
# **Remove Category, DataSource and Data_Value_Type because they have only one value (trivial, low variability)**

# %%
df = df[df.columns.difference(['Category', 'DataSource', 'Data_Value_Type'])]

# %% [markdown]
# #### **Remove Data_Value because its distribution is equivalent to that of Data_Value_Alt (correlation between attributes)**

# %%
df = df[df.columns.difference(['Data_Value'])]

# %% [markdown]
# #### Replace the null values of HighConfidenceLimit and LowConfidenceLimit with their mode value

# %%
def find_mode(vals) -> int:
    vals_count = {}
    
    # count the number of occurrences for each value
    for val in vals:
        if not val in vals_count.keys():
            vals_count[val] = 1
        else:
            vals_count[val] += 1
    # find the value with the maximum number of occurrences
    (mode, mode_count) = (-1, -1)
    for key in vals_count.keys():
        if vals_count[key] > mode_count:
            mode = key
            mode_count = vals_count[key]
    
    return mode

# %%
hcl_vals = df['HighConfidenceLimit'].dropna()
hcl_mode = find_mode(hcl_vals)

lcl_vals = df['LowConfidenceLimit'].dropna()
lcl_mode = find_mode(lcl_vals)
        
print(hcl_mode)
print(lcl_mode)

df.fillna(value={'HighConfidenceLimit' : hcl_mode, 'LowConfidenceLimit' : lcl_mode}, inplace=True)
df.info()
# Out:
# 4.1
# 0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42640 entries, 0 to 42639
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Break_Out            42640 non-null  category
#  1   Break_Out_Category   42640 non-null  category
#  2   Data_Value_Alt       42640 non-null  float64
#  3   Data_Value_Unit      42640 non-null  category
#  4   HighConfidenceLimit  42640 non-null  float64
#  5   LocationAbbr         42640 non-null  category
#  6   LowConfidenceLimit   42640 non-null  float64
#  7   Topic                42640 non-null  category
# dtypes: category(5), float64(3)
# memory usage: 1.2 MB

# %% [markdown]
# #### **Discretize attributes**

# %% [markdown]
# *We have decided not to discretize the float attributes (HighConfidenceLimit, LowConfidenceLimit and Data_Value_Alt), because they have different distributions*

# %% [markdown]
# #### **Binarization of categorical attributes**

# %%
cat_attributes = list(df.select_dtypes(include = ['category']).columns)
cat_attributes.remove('Topic')
df2 = pd.get_dummies(df, columns = cat_attributes)
new_attr_list = list(df2.columns)
new_attr_list.remove('Topic')
df2 = df2[new_attr_list]
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cat_attributes = list(df.select_dtypes(include = ['category']).columns)
#       2 cat_attributes.remove('Topic')
#       3 df2 = pd.get_dummies(df, columns = cat_attributes)
#
# NameError: name 'df' is not defined

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42640 entries, 0 to 42639
# Data columns (total 70 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Data_Value_Alt                  42640 non-null  float64
#  1   HighConfidenceLimit             42640 non-null  float64
#  2   LowConfidenceLimit              42640 non-null  float64
#  3   Break_Out_65+                   42640 non-null  bool
#  4   Break_Out_75+                   42640 non-null  bool
#  5   Break_Out_Female                42640 non-null  bool
#  6   Break_Out_Hispanic              42640 non-null  bool
#  7   Break_Out_Male                  42640 non-null  bool
#  8   Break_Out_Non-Hispanic Black    42640 non-null  bool
#  9   Break_Out_Non-Hispanic White    42640 non-null  bool
#  10  Break_Out_Other                 42640 non-null  bool
#  11  Break_Out_Overall               42640 non-null  bool
#  12  Break_Out_Category_Age          42640 non-null  bool
#  13  Break_Out_Category_Gender       42640 non-null  bool
#  14  Break_Out_Category_Overall      42640 non-null  bool
#  15  Break_Out_Category_Race         42640 non-null  bool
#  16  Data_Value_Unit_Percent (%)     42640 non-null  bool
#  17  Data_Value_Unit_Rate per 1,000  42640 non-null  bool
#  18  LocationAbbr_AK                 42640 non-null  bool
#  19  LocationAbbr_AL                 42640 non-null  bool
#  20  LocationAbbr_AR                 42640 non-null  bool
#  21  LocationAbbr_AZ                 42640 non-null  bool
#  22  LocationAbbr_CA                 42640 non-null  bool
#  23  LocationAbbr_CO                 42640 non-null  bool
#  24  LocationAbbr_CT                 42640 non-null  bool
#  25  LocationAbbr_DC                 42640 non-null  bool
#  26  LocationAbbr_DE                 42640 non-null  bool
#  27  LocationAbbr_FL                 42640 non-null  bool
#  28  LocationAbbr_GA                 42640 non-null  bool
#  29  LocationAbbr_HI                 42640 non-null  bool
#  30  LocationAbbr_IA                 42640 non-null  bool
#  31  LocationAbbr_ID                 42640 non-null  bool
#  32  LocationAbbr_IL                 42640 non-null  bool
#  33  LocationAbbr_IN                 42640 non-null  bool
#  34  LocationAbbr_KS                 42640 non-null  bool
#  35  LocationAbbr_KY                 42640 non-null  bool
#  36  LocationAbbr_LA                 42640 non-null  bool
#  37  LocationAbbr_MA                 42640 non-null  bool
#  38  LocationAbbr_MD                 42640 non-null  bool
#  39  LocationAbbr_ME                 42640 non-null  bool
#  40  LocationAbbr_MI                 42640 non-null  bool
#  41  LocationAbbr_MN                 42640 non-null  bool
#  42  LocationAbbr_MO                 42640 non-null  bool
#  43  LocationAbbr_MS                 42640 non-null  bool
#  44  LocationAbbr_MT                 42640 non-null  bool
#  45  LocationAbbr_NC                 42640 non-null  bool
#  46  LocationAbbr_ND                 42640 non-null  bool
#  47  LocationAbbr_NE                 42640 non-null  bool
#  48  LocationAbbr_NH                 42640 non-null  bool
#  49  LocationAbbr_NJ                 42640 non-null  bool
#  50  LocationAbbr_NM                 42640 non-null  bool
#  51  LocationAbbr_NV                 42640 non-null  bool
#  52  LocationAbbr_NY                 42640 non-null  bool
#  53  LocationAbbr_OH                 42640 non-null  bool
#  54  LocationAbbr_OK                 42640 non-null  bool
#  55  LocationAbbr_OR                 42640 non-null  bool
#  56  LocationAbbr_PA                 42640 non-null  bool
#  57  LocationAbbr_RI                 42640 non-null  bool
#  58  LocationAbbr_SC                 42640 non-null  bool
#  59  LocationAbbr_SD                 42640 non-null  bool
#  60  LocationAbbr_TN                 42640 non-null  bool
#  61  LocationAbbr_TX                 42640 non-null  bool
#  62  LocationAbbr_US                 42640 non-null  bool
#  63  LocationAbbr_UT                 42640 non-null  bool
#  64  LocationAbbr_VA                 42640 non-null  bool
#  65  LocationAbbr_VT                 42640 non-null  bool
#  66  LocationAbbr_WA                 42640 non-null  bool
#  67  LocationAbbr_WI                 42640 non-null  bool
#  68  LocationAbbr_WV                 42640 non-null  bool
#  69  LocationAbbr_WY                 42640 non-null  bool
# dtypes: bool(67), float64(3)
# memory usage: 3.7 MB

# %% [markdown]
# ### **Modeling**

# %% [markdown]
# #### Split dataset

# %%
from sklearn.model_selection import train_test_split
import numpy as np

x = np.array(df2.values)
y = np.array(df['Topic'].values)

seed = 12062024
test_size = .2
val_size = .2

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=seed)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=val_size, random_state=seed)

# %% [markdown]
# #### Create the models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, classification_report

# %%
models = []
models.append(('C45', DecisionTreeClassifier(criterion='entropy', random_state=seed)))
models.append(('CART', DecisionTreeClassifier(criterion='gini', random_state=seed)))
models.append(('GaussianNaiveBayes', GaussianNB()))
models.append(('NeuralNetwork', MLPClassifier(hidden_layer_sizes=(50, 10, ), max_iter=500, verbose=True, 
                                              random_state=seed)))


# evaluate each model in turn

for name, model in models:
    print(name)
    
    model.fit(x_train, y_train)
    y_val_pred = model.predict(x_val)
    
    print('Classification metrics: ')
    print(classification_report(y_val, y_val_pred))
    # print(f'Accuracy: {accuracy_score(y_val, y_val_pred):.2f}')
# Out:
# C45
# Classification metrics:
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.81      0.85      0.83       750
#                     Coronary Heart Disease       0.64      0.65      0.64       711
#      Diseases of the Heart (Heart Disease)       0.93      0.91      0.92       762
#                              Heart Failure       0.91      0.91      0.91      3085
#               Major Cardiovascular Disease       0.93      0.94      0.94       780
#                                     Stroke       0.69      0.66      0.67       735
#
#                                   accuracy                           0.85      6823
#                                  macro avg       0.82      0.82      0.82      6823
#                               weighted avg       0.85      0.85      0.85      6823
#
# CART
# Classification metrics:
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.80      0.86      0.83       750
#                     Coronary Heart Disease       0.63      0.67      0.65       711
#      Diseases of the Heart (Heart Disease)       0.93      0.92      0.92       762
#                              Heart Failure       0.91      0.90      0.91      3085
#               Major Cardiovascular Disease       0.94      0.93      0.93       780
#                                     Stroke       0.69      0.64      0.66       735
#
#                                   accuracy                           0.85      6823
#                                  macro avg       0.82      0.82      0.82      6823
#                               weighted avg       0.85      0.85      0.85      6823
#
# GaussianNaiveBayes
# Classification metrics:
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.59      0.60      0.59       750
#                     Coronary Heart Disease       0.49      0.72      0.58       711
#      Diseases of the Heart (Heart Disease)       0.78      0.80      0.79       762
#                              Heart Failure       1.00      0.76      0.86      3085
#               Major Cardiovascular Disease       0.81      0.79      0.80       780
#                                     Stroke       0.38      0.59      0.47       735
#
#                                   accuracy                           0.73      6823
#                                  macro avg       0.68      0.71      0.68      6823
#                               weighted avg       0.79      0.73      0.75      6823
#
# NeuralNetwork
# Iteration 1, loss = 2.10667665
# Iteration 2, loss = 1.68511633
# Iteration 3, loss = 1.42470028
# Iteration 4, loss = 1.11549643
# Iteration 5, loss = 0.99848962
# Iteration 6, loss = 0.81208017
# Iteration 7, loss = 0.59755171
# Iteration 8, loss = 0.50976488
# Iteration 9, loss = 0.46190089
# Iteration 10, loss = 0.43244978
# Iteration 11, loss = 0.41193320
# Iteration 12, loss = 0.39712470
# Iteration 13, loss = 0.38593077
# Iteration 14, loss = 0.37481098
# Iteration 15, loss = 0.36801653
# Iteration 16, loss = 0.36224837
# Iteration 17, loss = 0.35597179
# Iteration 18, loss = 0.34579481
# Iteration 19, loss = 0.33506226
# Iteration 20, loss = 0.32675185
# Iteration 21, loss = 0.32275158
# Iteration 22, loss = 0.31727442
# Iteration 23, loss = 0.31366177
# Iteration 24, loss = 0.31169714
# Iteration 25, loss = 0.30978475
# Iteration 26, loss = 0.30652815
# Iteration 27, loss = 0.30404736
# Iteration 28, loss = 0.30251069
# Iteration 29, loss = 0.30056666
# Iteration 30, loss = 0.29968212
# Iteration 31, loss = 0.29911554
# Iteration 32, loss = 0.29713538
# Iteration 33, loss = 0.29581252
# Iteration 34, loss = 0.29477631
# Iteration 35, loss = 0.29256523
# Iteration 36, loss = 0.29175103
# Iteration 37, loss = 0.29101909
# Iteration 38, loss = 0.29036717
# Iteration 39, loss = 0.28782554
# Iteration 40, loss = 0.28660475
# Iteration 41, loss = 0.28740425
# Iteration 42, loss = 0.28526544
# Iteration 43, loss = 0.28532420
# Iteration 44, loss = 0.28306402
# Iteration 45, loss = 0.28216170
# Iteration 46, loss = 0.28206525
# Iteration 47, loss = 0.27965603
# Iteration 48, loss = 0.28128868
# Iteration 49, loss = 0.27852865
# Iteration 50, loss = 0.27959141
# Iteration 51, loss = 0.27615084
# Iteration 52, loss = 0.27496101
# Iteration 53, loss = 0.27457656
# Iteration 54, loss = 0.27356702
# Iteration 55, loss = 0.27400684
# Iteration 56, loss = 0.27192916
# Iteration 57, loss = 0.27168256
# Iteration 58, loss = 0.27119129
# Iteration 59, loss = 0.27083050
# Iteration 60, loss = 0.27115597
# Iteration 61, loss = 0.26972914
# Iteration 150, loss = 0.24324571
# Iteration 151, loss = 0.24265979
# Iteration 152, loss = 0.24330161
# Iteration 153, loss = 0.24345449
# Iteration 154, loss = 0.24439362
# Iteration 155, loss = 0.24271780
# Iteration 156, loss = 0.24484178
# Iteration 157, loss = 0.24585583
# Iteration 158, loss = 0.24197778
# Iteration 159, loss = 0.24455302
# Iteration 160, loss = 0.24222185
# Iteration 161, loss = 0.24217515
# Iteration 162, loss = 0.24268194
# Iteration 163, loss = 0.24159493
# Iteration 164, loss = 0.24207562
# Iteration 165, loss = 0.24192145
# Iteration 166, loss = 0.24284399
# Iteration 167, loss = 0.24306229
# Iteration 168, loss = 0.24126337
# Iteration 169, loss = 0.24110605
# Iteration 170, loss = 0.24214721
# Iteration 171, loss = 0.24151553
# Iteration 172, loss = 0.24257136
# Iteration 173, loss = 0.24027460
# Iteration 174, loss = 0.24187104
# Iteration 175, loss = 0.24184912
# Iteration 176, loss = 0.23957472
# Iteration 177, loss = 0.23973615
# Iteration 178, loss = 0.24179267
# Iteration 179, loss = 0.24084590
# Iteration 180, loss = 0.24028932
# Iteration 181, loss = 0.24179565
# Iteration 182, loss = 0.24088796
# Iteration 183, loss = 0.23993728
# Iteration 184, loss = 0.23983900
# Iteration 185, loss = 0.24115022
# Iteration 186, loss = 0.24016324
# Iteration 187, loss = 0.24016746
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Classification metrics:
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.80      0.90      0.84       750
#                     Coronary Heart Disease       0.76      0.67      0.71       711
#      Diseases of the Heart (Heart Disease)       0.93      0.97      0.95       762
#                              Heart Failure       0.91      0.93      0.92      3085
#               Major Cardiovascular Disease       0.98      0.92      0.95       780
#                                     Stroke       0.74      0.67      0.70       735
#
#                                   accuracy                           0.88      6823
#                                  macro avg       0.85      0.84      0.85      6823
#                               weighted avg       0.87      0.88      0.87      6823

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print(f'[TRAIN] Accuracy: {knn.score(x_train, y_train)}')

y_val_pred = knn.predict(x_val)

print('Classification metrics: KNN')
print(classification_report(y_val, y_val_pred, zero_division=np.nan))
# Out:
# [TRAIN] Accuracy: 0.9033310124958774
# Classification metrics: KNN
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.84      0.84      0.84       750
#                     Coronary Heart Disease       0.72      0.62      0.67       711
#      Diseases of the Heart (Heart Disease)       0.93      0.90      0.92       762
#                              Heart Failure       0.89      0.92      0.91      3085
#               Major Cardiovascular Disease       0.93      0.93      0.93       780
#                                     Stroke       0.69      0.72      0.71       735
#
#                                   accuracy                           0.86      6823
#                                  macro avg       0.84      0.82      0.83      6823
#                               weighted avg       0.86      0.86      0.86      6823

# %% [markdown]
# #### For the meta-models we chose RandomForest

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=seed)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=12062024)

# %%
print(f'[TRAIN] Accuracy: {rf.score(x_train, y_train)}')

y_val_pred = rf.predict(x_val)

print('Classification metrics: RandomForest')
print(classification_report(y_val, y_val_pred, zero_division=np.nan))
# Out:
# [TRAIN] Accuracy: 0.9805782549745319
# Classification metrics: RandomForest
#                                             precision    recall  f1-score   support
#
# Acute Myocardial Infarction (Heart Attack)       0.84      0.86      0.85       750
#                     Coronary Heart Disease       0.69      0.66      0.68       711
#      Diseases of the Heart (Heart Disease)       0.94      0.92      0.93       762
#                              Heart Failure       0.91      0.92      0.91      3085
#               Major Cardiovascular Disease       0.94      0.95      0.94       780
#                                     Stroke       0.69      0.69      0.69       735
#
#                                   accuracy                           0.86      6823
#                                  macro avg       0.84      0.83      0.83      6823
#                               weighted avg       0.86      0.86      0.86      6823

# %% [markdown]
# ### **Evaluation**

# %% [markdown]
# #### **Due to the metrics in the report (f1-score, precision and recall) we choose as best model the Neural Network**

# %% [markdown]
# #### Predictions on test set

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
model = MLPClassifier(hidden_layer_sizes=(50, 10, ),max_iter=500, verbose=True, random_state=seed)

model.fit(x_train, y_train)
predictions = model.predict(x_test)
# Out:
# Iteration 1, loss = 2.10667665
# Iteration 2, loss = 1.68511633
# Iteration 3, loss = 1.42470028
# Iteration 4, loss = 1.11549643
# Iteration 5, loss = 0.99848962
# Iteration 6, loss = 0.81208017
# Iteration 7, loss = 0.59755171
# Iteration 8, loss = 0.50976488
# Iteration 9, loss = 0.46190089
# Iteration 10, loss = 0.43244978
# Iteration 11, loss = 0.41193320
# Iteration 12, loss = 0.39712470
# Iteration 13, loss = 0.38593077
# Iteration 14, loss = 0.37481098
# Iteration 15, loss = 0.36801653
# Iteration 16, loss = 0.36224837
# Iteration 17, loss = 0.35597179
# Iteration 18, loss = 0.34579481
# Iteration 19, loss = 0.33506226
# Iteration 20, loss = 0.32675185
# Iteration 21, loss = 0.32275158
# Iteration 22, loss = 0.31727442
# Iteration 23, loss = 0.31366177
# Iteration 24, loss = 0.31169714
# Iteration 25, loss = 0.30978475
# Iteration 26, loss = 0.30652815
# Iteration 27, loss = 0.30404736
# Iteration 28, loss = 0.30251069
# Iteration 29, loss = 0.30056666
# Iteration 30, loss = 0.29968212
# Iteration 31, loss = 0.29911554
# Iteration 32, loss = 0.29713538
# Iteration 33, loss = 0.29581252
# Iteration 34, loss = 0.29477631
# Iteration 35, loss = 0.29256523
# Iteration 36, loss = 0.29175103
# Iteration 37, loss = 0.29101909
# Iteration 38, loss = 0.29036717
# Iteration 39, loss = 0.28782554
# Iteration 40, loss = 0.28660475
# Iteration 41, loss = 0.28740425
# Iteration 42, loss = 0.28526544
# Iteration 43, loss = 0.28532420
# Iteration 44, loss = 0.28306402
# Iteration 45, loss = 0.28216170
# Iteration 46, loss = 0.28206525
# Iteration 47, loss = 0.27965603
# Iteration 48, loss = 0.28128868
# Iteration 49, loss = 0.27852865
# Iteration 50, loss = 0.27959141
# Iteration 51, loss = 0.27615084
# Iteration 52, loss = 0.27496101
# Iteration 53, loss = 0.27457656
# Iteration 54, loss = 0.27356702
# Iteration 55, loss = 0.27400684
# Iteration 56, loss = 0.27192916
# Iteration 57, loss = 0.27168256
# Iteration 58, loss = 0.27119129
# Iteration 59, loss = 0.27083050
# Iteration 60, loss = 0.27115597
# Iteration 61, loss = 0.26972914
# Iteration 62, loss = 0.26937836
# Iteration 63, loss = 0.26895657
# Iteration 152, loss = 0.24330161
# Iteration 153, loss = 0.24345449
# Iteration 154, loss = 0.24439362
# Iteration 155, loss = 0.24271780
# Iteration 156, loss = 0.24484178
# Iteration 157, loss = 0.24585583
# Iteration 158, loss = 0.24197778
# Iteration 159, loss = 0.24455302
# Iteration 160, loss = 0.24222185
# Iteration 161, loss = 0.24217515
# Iteration 162, loss = 0.24268194
# Iteration 163, loss = 0.24159493
# Iteration 164, loss = 0.24207562
# Iteration 165, loss = 0.24192145
# Iteration 166, loss = 0.24284399
# Iteration 167, loss = 0.24306229
# Iteration 168, loss = 0.24126337
# Iteration 169, loss = 0.24110605
# Iteration 170, loss = 0.24214721
# Iteration 171, loss = 0.24151553
# Iteration 172, loss = 0.24257136
# Iteration 173, loss = 0.24027460
# Iteration 174, loss = 0.24187104
# Iteration 175, loss = 0.24184912
# Iteration 176, loss = 0.23957472
# Iteration 177, loss = 0.23973615
# Iteration 178, loss = 0.24179267
# Iteration 179, loss = 0.24084590
# Iteration 180, loss = 0.24028932
# Iteration 181, loss = 0.24179565
# Iteration 182, loss = 0.24088796
# Iteration 183, loss = 0.23993728
# Iteration 184, loss = 0.23983900
# Iteration 185, loss = 0.24115022
# Iteration 186, loss = 0.24016324
# Iteration 187, loss = 0.24016746
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(f'Accuracy: {accuracy_score(y_test, predictions):.2f}')
# Out:
# Accuracy: 0.88

# %%
def make_confusion_matrix(cf, categories='auto', cbar=True, cmap='Blues', title=None):
    group_counts = [f'{value}\n' for value in cf.flatten()]

    box_labels = [f'{v1}'.strip() for v1 in group_counts]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])

    sb.heatmap(cf, annot=box_labels, fmt='', cmap=cmap, cbar=cbar, xticklabels=categories, yticklabels=categories)

    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    if title:
        plt.title(title)

# %%
categories = df['Topic'].unique()

plt.figure()

make_confusion_matrix(confusion_matrix(y_test, predictions), categories=categories, cmap='binary')

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(ticks=range(len(categories)), labels=categories)
plt.yticks(ticks=range(len(categories)), labels=categories)
plt.show()

# %% [markdown]
# ##### **Compute the Roc Curve for the best model**

# %%
from sklearn.metrics import roc_curve, auc

# %%
one_hot_encoding = np.array(pd.get_dummies(y_test, columns = ['Topic']))

model.fit(x_train, y_train)
prob = model.predict_proba(x_test)
# Out:
# Iteration 1, loss = 2.10667665
# Iteration 2, loss = 1.68511633
# Iteration 3, loss = 1.42470028
# Iteration 4, loss = 1.11549643
# Iteration 5, loss = 0.99848962
# Iteration 6, loss = 0.81208017
# Iteration 7, loss = 0.59755171
# Iteration 8, loss = 0.50976488
# Iteration 9, loss = 0.46190089
# Iteration 10, loss = 0.43244978
# Iteration 11, loss = 0.41193320
# Iteration 12, loss = 0.39712470
# Iteration 13, loss = 0.38593077
# Iteration 14, loss = 0.37481098
# Iteration 15, loss = 0.36801653
# Iteration 16, loss = 0.36224837
# Iteration 17, loss = 0.35597179
# Iteration 18, loss = 0.34579481
# Iteration 19, loss = 0.33506226
# Iteration 20, loss = 0.32675185
# Iteration 21, loss = 0.32275158
# Iteration 22, loss = 0.31727442
# Iteration 23, loss = 0.31366177
